# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt

# %%
freq_slider = widgets.FloatSlider(value=2.,min=1.,max=10.0,step=0.1,description='Frequency:',readout_format='.1f',)
range_slider = widgets.FloatRangeSlider(value=[-1., +1.],min=-5., max=+5., step=0.1,description='xlimit:',readout_format='.1f')
grid_button = widgets.ToggleButton(value=False,description='Grid',icon='check')
color_buttons = widgets.ToggleButtons(options=['blue', 'red', 'green'],description='Color:')
title_textbox = widgets.Text(value='Hello World',description='Title:')
color_picker = widgets.ColorPicker(concise=True,description='Background color:',value='#efefef')
button = widgets.Button(description='Plot')

# %%
def pl():
    xlim = range_slider.value
    freq = freq_slider.value
    grid = grid_button.value
    color = color_buttons.value
    title = title_textbox.value
    bgcolor = color_picker.value
    t = np.linspace(xlim[0], xlim[1], 1000)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),color=color)
    ax.patch.set_facecolor(bgcolor)
    plt.title(title)
    ax.grid(grid)

# %%
@button.on_click
def p(a):
    print(a)
    pl()

# %%
tab1 = VBox(children=[freq_slider,range_slider])
a= HBox(children=[title_textbox,color_picker,grid_button])
tab2 = VBox(children=[color_buttons,a])

# %%
tab = widgets.Tab(children=[tab1, tab2])
tab.set_title(0, 'information')
tab.set_title(1, 'styling')
VBox(children=[tab, button])
# Out:
# ...
# Button(description='Plot', style=ButtonStyle())

# %%
#another small example
from IPython.core.display import display,HTML
buttonShow= widgets.Button(description='Show')
def show():
    display(HTML('<h1>Welcome to Edureka!!</h1><p>Python Programming</p>'))
@buttonShow.on_click
def plot_on_click(b):
    show()
VBox(children=[buttonShow])
# Out:
# ...
# <h1>Welcome to Edureka!!</h1><p>Python Programming</p>
